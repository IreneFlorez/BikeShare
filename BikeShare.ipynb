# %%
# Importing packages and functions
import pandas as pd
import datetime # operations to parse dates

import calendar
import csv

# %%
pd.__version__
# Out:
# '0.23.4'

# %%
# supported cities, months, days
city_data = {'chicago': 'chicago.csv',
          'new york': 'new_york_city.csv',
          'washington': 'washington.csv'}
months = {v.lower(): k for k, v in enumerate(calendar.month_name)}
#months = ('january', 'february', 'march', 'april', 'may', 'june')
days = {v.lower(): k for k, v in enumerate(calendar.day_name)}
#days = ('monday','tuesday','wednesday','thursday','friday','saturday','sunday')

# %%
#get user input for city
def get_city():
    '''Asks the user for a city and returns the specified filter.
    Args:
        none.
    Returns:
        (str) City filter for the bikeshare data.
    '''
    while True:
        try:
            city = input('Hello! Let\'s explore some US bikeshare data!\nWould you like to see data for Chicago, New York, or Washington?\n')
        except ValueError:
            print('That is not a valid answer. Please try again.')
        if city.lower() in city_data.keys():
            return city.lower()
        else:
            print('That is not a valid answer. Please try again.')

# %%
# 1) pick a city   
city = get_city()
print('Great! We\'ll use %s.' % city)
# Out:
# Hello! Let's explore some US bikeshare data!
# Would you like to see data for Chicago, New York, or Washington?
# chicago
# Great! We'll use chicago.

# %%
def get_raw_city_data(city):
    '''Read CSV (comma-separated) file into DataFrame
    Args:
        city filter from get_city()
    Returns:
        raw_city_data df for the specified city's bikeshare data.
    '''
    raw_city_data = pd.read_csv(city_data[city])
    return raw_city_data

# %%
 # 3) load data
raw_city_data = get_raw_city_data(city)

# %%
raw_city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 9 columns):
# Unnamed: 0       300000 non-null int64
# Start Time       300000 non-null object
# End Time         300000 non-null object
# Trip Duration    300000 non-null int64
# Start Station    300000 non-null object
# End Station      300000 non-null object
# User Type        300000 non-null object
# Gender           238948 non-null object
# Birth Year       238981 non-null float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 20.6+ MB

# %%
raw_city_data
# Out:
#         Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0          1423854  2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1           955915  2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2             9031  2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3           304487  2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4            45207  2017-01-17 14:53:07  2017-01-17 15:02:01            534
# 5          1473887  2017-06-26 09:01:20  2017-06-26 09:11:06            586
# 6           961916  2017-05-26 09:41:44  2017-05-26 09:46:25            281
# 7            65924  2017-01-21 14:28:38  2017-01-21 14:40:41            723
# 8           606841  2017-04-20 16:08:51  2017-04-20 16:20:20            689
# 9           135470  2017-02-06 18:00:47  2017-02-06 18:09:00            493
# 10          175805  2017-02-15 07:09:55  2017-02-15 07:14:56            301
# 11           71678  2017-01-22 15:15:45  2017-01-22 15:31:02            917
# 12           19061  2017-01-08 16:03:00  2017-01-08 16:07:37            277
# 13         1023296  2017-05-30 15:46:18  2017-05-30 15:52:12            354
# 14          611000  2017-04-20 19:26:33  2017-04-20 19:35:08            515
# 15          958716  2017-05-25 22:59:33  2017-05-25 23:07:19            466
# 16          718598  2017-05-03 13:20:38  2017-05-03 13:31:13            635
# 17          931608  2017-05-23 08:08:25  2017-05-23 08:11:09            164
# 299988       Lake Shore Dr & Monroe St                     Adler Planetarium
# 299989           Green St & Madison St                  Canal St & Taylor St
# 299990              Rush St & Cedar St         Pine Grove Ave & Waveland Ave
# 299991    Milwaukee Ave & Wabansia Ave             Ashland Ave & Chicago Ave
# 299992       Sheffield Ave & Willow St              Halsted St & Dickens Ave
# 299993       Lake Shore Dr & Monroe St                  McClurg Ct & Erie St
# 299994           Indiana Ave & 31st St                   MLK Jr Dr & 29th St
# 299995         Orleans St & Elm St (*)           Sheffield Ave & Webster Ave
# 299996      Ashland Ave & Blackhawk St                     Clark St & Elm St
# 299997   Ravenswood Ave & Lawrence Ave          Stockton Dr & Wrightwood Ave
# 299998       Sheffield Ave & Willow St                Clark St & Chicago Ave
# 299999       Wacker Dr & Washington St               Damen Ave & Division St
#
#          User Type  Gender  Birth Year
# 0       Subscriber    Male      1992.0
# 1       Subscriber  Female      1992.0
# 2       Subscriber    Male      1981.0
# 3       Subscriber    Male      1986.0
# 4       Subscriber    Male      1975.0
# 5       Subscriber    Male      1990.0
# 6       Subscriber  Female      1983.0
# 7         Customer     NaN         NaN
# 8       Subscriber    Male      1984.0
# 9       Subscriber    Male      1979.0
# 10      Subscriber  Female      1993.0
# 11      Subscriber    Male      1964.0
# 12      Subscriber    Male      1961.0
# 13      Subscriber    Male      1985.0
# 14      Subscriber    Male      1984.0
# 15      Subscriber  Female      1985.0
# 16      Subscriber    Male      1967.0
# 17      Subscriber    Male      1990.0
# 18      Subscriber    Male      1987.0
# 19        Customer     NaN         NaN
# 20      Subscriber  Female      1992.0
# 21      Subscriber    Male      1985.0
# 22      Subscriber    Male      1980.0
# 23      Subscriber  Female      1989.0
# 24      Subscriber    Male      1992.0
# 25      Subscriber    Male      1968.0
# 26      Subscriber  Female      1985.0
# 27      Subscriber    Male      1974.0
# 28      Subscriber    Male      1989.0
# 29      Subscriber    Male      1970.0
# ...            ...     ...         ...
# 299970  Subscriber    Male      1990.0
# 299971  Subscriber    Male      1976.0
# 299972  Subscriber  Female      1978.0
# 299973    Customer     NaN         NaN
# 299974  Subscriber    Male      2000.0
# 299975  Subscriber    Male      1958.0
# 299976  Subscriber    Male      1990.0
# 299977  Subscriber    Male      1989.0
# 299978  Subscriber  Female      1971.0
# 299979    Customer     NaN         NaN
# 299980  Subscriber  Female      1976.0
# 299981    Customer     NaN         NaN
# 299982  Subscriber    Male      1993.0
# 299983    Customer     NaN         NaN
# 299984  Subscriber    Male      1987.0
# 299985  Subscriber    Male      1991.0
# 299986    Customer     NaN         NaN
# 299987    Customer     NaN         NaN
# 299988    Customer     NaN         NaN
# 299989    Customer     NaN         NaN
# 299990  Subscriber    Male      1989.0
# 299991  Subscriber  Female      1982.0
# 299992  Subscriber    Male      1955.0
# 299993    Customer     NaN         NaN
# 299994  Subscriber    Male      1988.0
# 299995  Subscriber    Male      1965.0
# 299996    Customer     NaN         NaN
# 299997  Subscriber  Female      1988.0
# 299998    Customer     NaN         NaN
# 299999  Subscriber    Male      1984.0
#
# [300000 rows x 9 columns]

# %%
def clean_data(raw_city_data):
    '''Read CSV (comma-separated) file into DataFrame
# 8       Subscriber    Male      1984.0
# 9       Subscriber    Male      1979.0
# 10      Subscriber  Female      1993.0
# 11      Subscriber    Male      1964.0
# 12      Subscriber    Male      1961.0
# 13      Subscriber    Male      1985.0
# 14      Subscriber    Male      1984.0
# 15      Subscriber  Female      1985.0
# 16      Subscriber    Male      1967.0
# 17      Subscriber    Male      1990.0
# 18      Subscriber    Male      1987.0
# 19        Customer     NaN         NaN
# 20      Subscriber  Female      1992.0
# 21      Subscriber    Male      1985.0
# 22      Subscriber    Male      1980.0
# 23      Subscriber  Female      1989.0
# 24      Subscriber    Male      1992.0
# 25      Subscriber    Male      1968.0
# 26      Subscriber  Female      1985.0
# 27      Subscriber    Male      1974.0
# 28      Subscriber    Male      1989.0
# 29      Subscriber    Male      1970.0
# ...            ...     ...         ...
# 299970  Subscriber    Male      1990.0
# 299971  Subscriber    Male      1976.0
# 299972  Subscriber  Female      1978.0
# 299973    Customer     NaN         NaN
# 299974  Subscriber    Male      2000.0
# 299975  Subscriber    Male      1958.0
# 299976  Subscriber    Male      1990.0
# 299977  Subscriber    Male      1989.0
# 299978  Subscriber  Female      1971.0
# 299979    Customer     NaN         NaN
# 299980  Subscriber  Female      1976.0
# 299981    Customer     NaN         NaN
# 299982  Subscriber    Male      1993.0
# 299983    Customer     NaN         NaN
# 299984  Subscriber    Male      1987.0
# 299985  Subscriber    Male      1991.0
# 299986    Customer     NaN         NaN
# 299987    Customer     NaN         NaN
# 299988    Customer     NaN         NaN
# 299989    Customer     NaN         NaN
# 299990  Subscriber    Male      1989.0
# 299991  Subscriber  Female      1982.0
# 299992  Subscriber    Male      1955.0
# 299993    Customer     NaN         NaN
# 299994  Subscriber    Male      1988.0
# 299995  Subscriber    Male      1965.0
# 299996    Customer     NaN         NaN
# 299997  Subscriber  Female      1988.0
# 299998    Customer     NaN         NaN
# 299999  Subscriber    Male      1984.0
#
#                                                   journey
# 0         Wood St & Hubbard St to Damen Ave & Chicago Ave
# 1       Theater on the Lake to Sheffield Ave & Wavelan...
# 2               May St & Taylor St to Wood St & Taylor St
# 3       Christiana Ave & Lawrence Ave to St. Louis Ave...
# 4       Clark St & Randolph St to Desplaines St & Jack...
# 5       Clinton St & Washington Blvd to Canal St & Tay...
# 6           Ashland Ave & Lake St to Wood St & Hubbard St
# 7       Larrabee St & Kingsbury St to Larrabee St & Ar...
# 8       Sedgwick St & Huron St to Halsted St & Blackha...
# 9       Stetson Ave & South Water St to Clinton St & W...
# 10       Broadway & Barry Ave to Wilton Ave & Belmont Ave
# 11      Southport Ave & Wellington Ave to Clark St & S...
# 12      Green St & Madison St to Ada St & Washington Blvd
# 13        Larrabee St & Kingsbury St to Clark St & Elm St
# 14      Canal St & Madison St to Racine Ave (May St) &...
# 15      Clark St & Armitage Ave to Sheffield Ave & Wri...
# 16         Ada St & Washington Blvd to Daley Center Plaza
# 17      Damen Ave & Cortland St to Marshfield Ave & Co...
# 18        State St & Pearson St to Clark St & Schiller St
# 19                    Adler Planetarium to Burnham Harbor
# 20      Michigan Ave & Oak St to Halsted St & Wrightwo...
# 21           Rush St & Cedar St to Halsted St & Willow St
# 22      Clarendon Ave & Leland Ave to Lake Shore Dr & ...
# 23      Bissell St & Armitage Ave to Orleans St & Ches...
# 24      Wabash Ave & Roosevelt Rd to Halsted St & Roos...
# 25           Rush St & Cedar St to Halsted St & Roscoe St
# 26      Loomis St & Jackson Blvd to Peoria St & Jackso...
# 27        Canal St & Madison St to Clark St & Randolph St
# 28      Clinton St & Lake St to Mies van der Rohe Way ...
# 29      Halsted St & Dickens Ave to Halsted St & Wrigh...
# ...                                                   ...
# 299970  Cornell Ave & Hyde Park Blvd to Ellis Ave & 55...
# 299971              Dusable Harbor to Theater on the Lake
# 299972  Racine Ave & Wrightwood Ave to Clark St & Well...
# 299973    Indiana Ave & Roosevelt Rd to Adler Planetarium
# 299974  Halsted St & Maxwell St to Clark St & 9th St (...
# 299975  Dayton St & North Ave to Sheffield Ave & Kings...
# 299976  Paulina Ave & North Ave to Bissell St & Armita...
# 299977  Clinton St & Jackson Blvd to Dearborn Pkwy & D...
# 299978   St. Clair St & Erie St to Michigan Ave & Lake St
# 299979  Bissell St & Armitage Ave to Clark St & Armita...
# 299980       Theater on the Lake to Michigan Ave & Oak St
# 299981  Franklin St & Jackson Blvd to Lake Shore Dr & ...
# 299982  Kingsbury St & Kinzie St to Clinton St & Jacks...
# 299983  Lakeview Ave & Fullerton Pkwy to Halsted St & ...
# 299984  Damen Ave & Wellington Ave to Clifton Ave & La...
# 299985  Canal St & Monroe St (*) to Milwaukee Ave & Gr...
# 299986       Shedd Aquarium to LaSalle St & Washington St
# 299987  Sheffield Ave & Wellington Ave to Larrabee St ...
# 299988     Lake Shore Dr & Monroe St to Adler Planetarium
# 299989      Green St & Madison St to Canal St & Taylor St
# 299990  Rush St & Cedar St to Pine Grove Ave & Wavelan...
# 299991  Milwaukee Ave & Wabansia Ave to Ashland Ave & ...
# 299992  Sheffield Ave & Willow St to Halsted St & Dick...
# 299993  Lake Shore Dr & Monroe St to McClurg Ct & Erie St
# 299994       Indiana Ave & 31st St to MLK Jr Dr & 29th St
# 299995  Orleans St & Elm St (*) to Sheffield Ave & Web...
# 299996    Ashland Ave & Blackhawk St to Clark St & Elm St
# 299997  Ravenswood Ave & Lawrence Ave to Stockton Dr &...
# 299998  Sheffield Ave & Willow St to Clark St & Chicag...
# 299999  Wacker Dr & Washington St to Damen Ave & Divis...
#
# [300000 rows x 10 columns]

# %%
raw_city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 10 columns):
# unnamed:_0       300000 non-null int64
# start_time       300000 non-null object
# end_time         300000 non-null object
# trip_duration    300000 non-null int64
# start_station    300000 non-null object
# end_station      300000 non-null object
# user_type        300000 non-null object
# gender           238948 non-null object
# birth_year       238981 non-null float64
# journey          300000 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 22.9+ MB

# %%
def parse_data(raw_city_data):
    '''Read CSV (comma-separated) file into DataFrame
    Args:
        (obj) raw_city_data from get_raw_city_data(city)
    Returns:
        (obj) parsed raw_city_data   
    ''' 
    # parse datetime 
    raw_city_data['start_time'] = pd.to_datetime(raw_city_data['start_time'])
    raw_city_data['end_time'] = pd.to_datetime(raw_city_data['end_time'])
    
# 19        Customer     NaN         NaN
# 20      Subscriber  Female      1992.0
# 21      Subscriber    Male      1985.0
# 22      Subscriber    Male      1980.0
# 23      Subscriber  Female      1989.0
# 24      Subscriber    Male      1992.0
# 25      Subscriber    Male      1968.0
# 26      Subscriber  Female      1985.0
# 27      Subscriber    Male      1974.0
# 28      Subscriber    Male      1989.0
# 29      Subscriber    Male      1970.0
# ...            ...     ...         ...
# 299970  Subscriber    Male      1990.0
# 299971  Subscriber    Male      1976.0
# 299972  Subscriber  Female      1978.0
# 299973    Customer     NaN         NaN
# 299974  Subscriber    Male      2000.0
# 299975  Subscriber    Male      1958.0
# 299976  Subscriber    Male      1990.0
# 299977  Subscriber    Male      1989.0
# 299978  Subscriber  Female      1971.0
# 299979    Customer     NaN         NaN
# 299980  Subscriber  Female      1976.0
# 299981    Customer     NaN         NaN
# 299982  Subscriber    Male      1993.0
# 299983    Customer     NaN         NaN
# 299984  Subscriber    Male      1987.0
# 299985  Subscriber    Male      1991.0
# 299986    Customer     NaN         NaN
# 299987    Customer     NaN         NaN
# 299988    Customer     NaN         NaN
# 299989    Customer     NaN         NaN
# 299990  Subscriber    Male      1989.0
# 299991  Subscriber  Female      1982.0
# 299992  Subscriber    Male      1955.0
# 299993    Customer     NaN         NaN
# 299994  Subscriber    Male      1988.0
# 299995  Subscriber    Male      1965.0
# 299996    Customer     NaN         NaN
# 299997  Subscriber  Female      1988.0
# 299998    Customer     NaN         NaN
# 299999  Subscriber    Male      1984.0
#
#                                                   journey  month day_of_week  \
# 0         Wood St & Hubbard St to Damen Ave & Chicago Ave      6      Friday
# 1       Theater on the Lake to Sheffield Ave & Wavelan...      5    Thursday
# 2               May St & Taylor St to Wood St & Taylor St      1   Wednesday
# 3       Christiana Ave & Lawrence Ave to St. Louis Ave...      3      Monday
# 4       Clark St & Randolph St to Desplaines St & Jack...      1     Tuesday
# 5       Clinton St & Washington Blvd to Canal St & Tay...      6      Monday
# 6           Ashland Ave & Lake St to Wood St & Hubbard St      5      Friday
# 7       Larrabee St & Kingsbury St to Larrabee St & Ar...      1    Saturday
# 8       Sedgwick St & Huron St to Halsted St & Blackha...      4    Thursday
# 9       Stetson Ave & South Water St to Clinton St & W...      2      Monday
# 10       Broadway & Barry Ave to Wilton Ave & Belmont Ave      2   Wednesday
# 11      Southport Ave & Wellington Ave to Clark St & S...      1      Sunday
# 12      Green St & Madison St to Ada St & Washington Blvd      1      Sunday
# 13        Larrabee St & Kingsbury St to Clark St & Elm St      5     Tuesday
# 14      Canal St & Madison St to Racine Ave (May St) &...      4    Thursday
# 15      Clark St & Armitage Ave to Sheffield Ave & Wri...      5    Thursday
# 16         Ada St & Washington Blvd to Daley Center Plaza      5   Wednesday
# 17      Damen Ave & Cortland St to Marshfield Ave & Co...      5     Tuesday
# 18        State St & Pearson St to Clark St & Schiller St      6      Sunday
# 19                    Adler Planetarium to Burnham Harbor      4    Saturday
# 20      Michigan Ave & Oak St to Halsted St & Wrightwo...      5     Tuesday
# 21           Rush St & Cedar St to Halsted St & Willow St      6      Friday
# 18        21
# 19        11
# 20         6
# 21        12
# 22        15
# 23        19
# 24         9
# 25        20
# 26         9
# 27         7
# 28        18
# 29        19
# ...      ...
# 299970    11
# 299971     9
# 299972     8
# 299973    12
# 299974     7
# 299975    11
# 299976    18
# 299977    17
# 299978     8
# 299979    12
# 299980     9
# 299981    14
# 299982    17
# 299983    14
# 299984    17
# 299985    17
# 299986    16
# 299987    15
# 299988    13
# 299989    13
# 299990    15
# 299991    19
# 299992    16
# 299993    17
# 299994    17
# 299995    13
# 299996    19
# 299997     9
# 299998    17
# 299999    12
#
# [300000 rows x 13 columns]

# %%
raw_city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 13 columns):
# unnamed:_0       300000 non-null int64
# start_time       300000 non-null datetime64[ns]
# end_time         300000 non-null datetime64[ns]
# trip_duration    300000 non-null int64
# start_station    300000 non-null object
# end_station      300000 non-null object
# user_type        300000 non-null object
# gender           238948 non-null object
# birth_year       238981 non-null float64
# journey          300000 non-null object
# month            300000 non-null int64
# day_of_week      300000 non-null object
# hour             300000 non-null int64
# dtypes: datetime64[ns](2), float64(1), int64(4), object(6)
# memory usage: 29.8+ MB

# %%
def filter_data(raw_city_data):
    '''Asks the user for a time period and filter the basic processed data according 
        to the specified filter and returns the filtered data and the filter name.
    Args:
        (obj) basic processed data
    Returns:
        (obj) filtered data
    '''

    # loop for handling invalid entries
    while True: 
        time_period = input('Would you like to filter the data by month, day, or not at all? Type "none" for no time filter.\n').lower()
        print('Great! Time period selected: %s' % time_period)
        if time_period in ('month', 'day', 'none'):
            break
        print('Enter a valid input provided in the options')

    if time_period =='month':
    #ask for the month of choice
        while True:
            month_selection = input('Select a month, January - June \n')
            if month_selection.lower() in months:
                print('Great! We\'ll use %s.' % month_selection)
                month_selection = months.get(month_selection)
                filtered_city_data = raw_city_data[raw_city_data['start_time'].dt.month==month_selection]
                
                break

            print('That is not a valid answer. Please try again.')
            
    elif time_period =='day':
        while True:
            day_selection = input('Which day of the week? \n')
            if day_selection.lower() in days:
                print('Great! We\'ll use %s.' % day_selection)
                day_selection = days.get(day_selection)
                filtered_city_data = raw_city_data[raw_city_data['start_time'].dt.dayofweek==day_selection]
                break

            print('That is not a valid answer. Please try again.')
                
    else:
        filtered_city_data = raw_city_data # for none option

    return filtered_city_data

# %%
    #5) filter data
filtered_city_data = filter_data(raw_city_data)
# Out:
# Would you like to filter the data by month, day, or not at all? Type "none" for no time filter.
# month
# Great! Time period selected: month
# Select a month, January - June
# january
# Great! We'll use january.

# %%
filtered_city_data
# Out:
#         unnamed:_0          start_time            end_time  trip_duration  \
# 2             9031 2017-01-04 08:27:49 2017-01-04 08:34:45            416
# 4            45207 2017-01-17 14:53:07 2017-01-17 15:02:01            534
# 7            65924 2017-01-21 14:28:38 2017-01-21 14:40:41            723
# 11           71678 2017-01-22 15:15:45 2017-01-22 15:31:02            917
# 12           19061 2017-01-08 16:03:00 2017-01-08 16:07:37            277
# 39           93723 2017-01-26 19:45:41 2017-01-26 19:59:31            830
# 91           80745 2017-01-24 10:51:56 2017-01-24 11:12:04           1208
# 117           7325 2017-01-03 17:57:21 2017-01-03 18:06:04            523
# 299741        Kedzie Ave & Chicago Ave          Kimball Ave & Belmont Ave
# 299752   Ravenswood Ave & Lawrence Ave       Ravenswood Ave & Berteau Ave
# 299764     Dearborn Pkwy & Delaware Pl           Wells St & Evergreen Ave
# 299777     Campbell Ave & Montrose Ave            Clark St & Armitage Ave
# 299778       Clinton St & Jackson Blvd         Racine Ave & Congress Pkwy
# 299836       Columbus Dr & Randolph St            Streeter Dr & Grand Ave
# 299841             Wells St & Huron St         Wilton Ave & Diversey Pkwy
# 299848   Halsted St & Blackhawk St (*)          Clinton St & Jackson Blvd
# 299854            Orleans St & Ohio St              Canal St & Madison St
# 299857       Michigan Ave & Pearson St             Wabash Ave & Wacker Pl
# 299859         Clark St & Armitage Ave              Michigan Ave & Oak St
# 299878       Ashland Ave & Division St            Damen Ave & Division St
# 299896              Wells St & Polk St            Dearborn St & Monroe St
# 299897              Daley Center Plaza               Rush St & Hubbard St
# 299908              State St & 33rd St               Rhodes Ave & 32nd St
# 299920       Clinton St & Jackson Blvd             Damen Ave & Madison St
# 299946           Dayton St & North Ave             Leavitt St & North Ave
# 299958      Indiana Ave & Roosevelt Rd          Michigan Ave & Madison St
# 299972     Racine Ave & Wrightwood Ave          Clark St & Wellington Ave
# 299975           Dayton St & North Ave       Sheffield Ave & Kingsbury St
# 299993       Lake Shore Dr & Monroe St               McClurg Ct & Erie St
# 299995         Orleans St & Elm St (*)        Sheffield Ave & Webster Ave
#
#          user_type  gender  birth_year  \
# 2       Subscriber    Male      1981.0
# 4       Subscriber    Male      1975.0
# 7         Customer     NaN         NaN
# 11      Subscriber    Male      1964.0
# 12      Subscriber    Male      1961.0
# 39      Subscriber    Male      1977.0
# 91      Subscriber    Male      1985.0
# 117     Subscriber    Male      1989.0
# 120     Subscriber    Male      1984.0
# 121     Subscriber    Male      1992.0
# 130     Subscriber    Male      1967.0
# 143     Subscriber    Male      1954.0
# 167     Subscriber    Male      1990.0
# 187     Subscriber    Male      1990.0
# 202     Subscriber    Male      1978.0
# 208     Subscriber  Female      1988.0
# 210     Subscriber    Male      1956.0
# 234     Subscriber    Male      1966.0
# 236     Subscriber  Female      1990.0
# 237     Subscriber  Female      1988.0
# 245     Subscriber    Male      1986.0
# 253     Subscriber    Male      1972.0
# 256     Subscriber    Male      1987.0
# 269     Subscriber    Male      1988.0
# 273     Subscriber    Male      1983.0
# 291     Subscriber    Male      1984.0
# 341     Subscriber    Male      1981.0
# 363     Subscriber    Male      1988.0
# 366     Subscriber    Male      1968.0
# 383     Subscriber  Female      1995.0
# ...            ...     ...         ...
# 299640  Subscriber    Male      1956.0
# 299642  Subscriber    Male      1985.0
# 299643  Subscriber  Female      1968.0
# 299653  Subscriber  Female      1993.0
# 299685  Subscriber    Male      1984.0
# 299687  Subscriber    Male      1991.0
# 299722  Subscriber  Female      1984.0
# 299738  Subscriber    Male      1985.0
# 299741  Subscriber    Male      1975.0
# 299752  Subscriber    Male      1994.0
# 299764  Subscriber    Male      1978.0
# 299777  Subscriber    Male      1990.0
# 299778  Subscriber    Male      1987.0
# 299653  Clinton St & Tilden St to Franklin St & Monroe St      1      Friday
# 299685  Desplaines St & Kinzie St to Sedgwick St & Web...      1    Thursday
# 299687  Orleans St & Elm St (*) to Stetson Ave & South...      1   Wednesday
# 299722  Wells St & Evergreen Ave to Franklin St & Lake St      1    Thursday
# 299738  Canal St & Madison St to Desplaines St & Kinzi...      1     Tuesday
# 299741  Kedzie Ave & Chicago Ave to Kimball Ave & Belm...      1      Friday
# 299752  Ravenswood Ave & Lawrence Ave to Ravenswood Av...      1      Sunday
# 299764  Dearborn Pkwy & Delaware Pl to Wells St & Ever...      1   Wednesday
# 299777  Campbell Ave & Montrose Ave to Clark St & Armi...      1      Friday
# 299778  Clinton St & Jackson Blvd to Racine Ave & Cong...      1    Thursday
# 299836  Columbus Dr & Randolph St to Streeter Dr & Gra...      1      Friday
# 299841  Wells St & Huron St to Wilton Ave & Diversey Pkwy      1    Thursday
# 299848  Halsted St & Blackhawk St (*) to Clinton St & ...      1   Wednesday
# 299854      Orleans St & Ohio St to Canal St & Madison St      1      Monday
# 299857  Michigan Ave & Pearson St to Wabash Ave & Wack...      1    Thursday
# 299859   Clark St & Armitage Ave to Michigan Ave & Oak St      1   Wednesday
# 299878  Ashland Ave & Division St to Damen Ave & Divis...      1      Monday
# 299896      Wells St & Polk St to Dearborn St & Monroe St      1   Wednesday
# 299897         Daley Center Plaza to Rush St & Hubbard St      1   Wednesday
# 299908         State St & 33rd St to Rhodes Ave & 32nd St      1      Sunday
# 299920  Clinton St & Jackson Blvd to Damen Ave & Madis...      1     Tuesday
# 299946    Dayton St & North Ave to Leavitt St & North Ave      1    Saturday
# 299958  Indiana Ave & Roosevelt Rd to Michigan Ave & M...      1     Tuesday
# 299972  Racine Ave & Wrightwood Ave to Clark St & Well...      1     Tuesday
# 299975  Dayton St & North Ave to Sheffield Ave & Kings...      1   Wednesday
# 299993  Lake Shore Dr & Monroe St to McClurg Ct & Erie St      1    Saturday
# 299995  Orleans St & Elm St (*) to Sheffield Ave & Web...      1    Saturday
#
#         hour
# 2          8
# 4         14
# 7         14
# 11        15
# 12        16
# 39        19
# 91        10
# 117       17
# 120       21
# 121       14
# 130       18
# 143       13
# 167       18
# 187       20
# 202       21
# 208        8
# 210       17
# 234       16
# 236       11
# 237       18
# 245        7
# 253        7
# 256       23
# 269        8
# 273       20
# 291       19
# 341       19
# 363       19
# 366       16
# 383       13
# ...      ...
# 299640    12
# 299642    18
# 299643    17
# 299653     8
# 299685    14
# 299687     8
# 299722     8
# 299738     7
# 299741    16
# 299752    13
# 299764    17
# 299777    11
# 299778    10
# 299836    16
# 299841    17
# 299848    17
# 299854     6
# 299857    14
# 299859     7
# 299878    19
# 299896     9
# 299897    17
# 299908     2
# 299920    17
# 299946    21
# 299958    11
# 299972     8
# 299975    11
# 299993    17
# 299995    13
#
# [21809 rows x 13 columns]

# %%
def display_statistics(filtered_city_data):
    '''Displays city data statistics (trip, user) on the specified filters
    Args:
        (ob) filtered_city_data
    Returns:
        statistics
    '''
    #Print heading that specifies selected city, filters
    print('\n')
    print('-------------------------------------')    


    """Display statistics on the most popular stations and trip."""
    print('\nStation Info:')
    # display most commonly used start station & end station
    popular_start_station = filtered_city_data['start_station'].mode().to_string(index = False)
    popular_end_station = filtered_city_data['end_station'].mode().to_string(index = False)
    print('Popular Start Station: ', popular_start_station)
    print('Popular End Station: ', popular_end_station)

    # display most frequent combination of start station and end station trip
    popular_journey = filtered_city_data['journey'].mode().to_string(index = False)
    print('Popular Journey: ', popular_journey)

    """Displays statistics on the total and average trip duration."""
    print('\nOther Ridership Data:')
    # display total travel time
    total_travel_time = filtered_city_data['trip_duration'].sum()
    print('Total Time Travel:', total_travel_time)
    # display mean travel time
    mean_travel_time = filtered_city_data['trip_duration'].mean()
    print('Mean Time Travel:', mean_travel_time)

    """Displays statistics on bikeshare users."""
    print('\nUser Info:')
    #Display counts of user types
    user_types=filtered_city_data['user_type'].value_counts()
    print(user_types)
    print('\n')
    
    if city == 'chicago' or city == 'new york': 
        user_statistics(filtered_city_data)

# %%
def display_month_day_hour_statistics(filtered_city_data):
    '''Displays city data statistics (month, day, hour) on the specified filters.
       Example: Finds and prints the most popular day of week (Monday, Tuesday, etc.) for start time.
    Args:
        (ob) filtered_city_data
    Returns:
        statistics
    '''
    #Print heading that specifies selected city, filters
    print('\n')
    print('-------------------------------------')
    # display total number of trips for this city and filter
    #print('Total trips: ', (filtered_city_data['Start_Time'].count()))
    
    """Display statistics on the most frequent times of travel."""
    print('\nTrip Info:')
    # display the most common month
    popular_month = filtered_city_data['month'].mode()[0]
    print(popular_month, 'is the month with the highest ridership')

    # display the most common day of week
    popular_day = filtered_city_data['day_of_week'].mode()[0]
    print(popular_day, 'is the day of the week with the highest ridership')
        
    # display the most common hour (from 0 to 23)
    popular_hour = filtered_city_data['hour'].mode()[0]
    print(popular_hour, 'is the most common trip start hour')

# %%
def user_statistics(filtered_city_data):
    '''Displays city data statistics on the specified filters, for specified cities
    Args:
        (obj) filtered_city_data
    Returns:
        user statistics for chicago and nyc data only 
    '''
    #Display counts of gender
    #Display earliest, most recent, and most common year of birth
    #gender_count = city_data.groupby('Gender')['Gender'].count()
    gender_count = filtered_city_data['gender'].value_counts()
    print(gender_count)
    earliest = int(filtered_city_data['birth_year'].min(skipna=True))
    recent = int(filtered_city_data['birth_year'].max(skipna=True))
    mode = int(filtered_city_data['birth_year'].mode())
    print('The oldest birth year in the dataset is listed as {}.\nThe most recent birth year in the dataset is {}.'
          '\nThe most common birth year in the dataset is {}.'.format(earliest, recent, mode))
    print('\n')
 


    #finding min without including zeros with pandas and numpy (instead of skipna...if float was updated to int and na filled with zeros)
    #https://stackoverflow.com/questions/51481884/min-value-in-each-column-of-a-data-frame-excluding-zeros
    #https://stackoverflow.com/questions/51594489/find-minimum-without-zero-and-nan-in-pandas-dataframe
    #https://stackoverflow.com/questions/27733431/finding-an-average-but-ignoring-any-zero-in-a-list-python

# %% [markdown]
# a = filtered_city_data[filtered_city_data.gt(birth_year)].min(0)
# print(a)

# %%
display_statistics(filtered_city_data)
# Out:
# -------------------------------------
#
# Station Info:
# Popular Start Station:  Clinton St & Washington Blvd
# Popular End Station:  Clinton St & Washington Blvd
# Popular Journey:  LaSalle St & Jackson Blvd to Canal St & Madiso...
#
# Other Ridership Data:
# Total Time Travel: 14826150
# Mean Time Travel: 679.8179650602962
#
# User Info:
# Subscriber    20794
# Customer       1015
# Name: user_type, dtype: int64
#
#
# Male      16745
# Female     4059
# Name: gender, dtype: int64
# The oldest birth year in the dataset is listed as 1899.
# The most recent birth year in the dataset is 2000.
# The most common birth year in the dataset is 1989.

# %%
def display_data(filtered_city_data, row):
    """
    Asks the user if they would you like to view individual trip data and loads the raw data 
    Args:
        (obj) filtered city_data
        ilocs
    Returns:
        data in detail
    """
    display = input('\nWould you like to view individual trip data?'
                    ' Type \'yes\' or \'no\'.\n').lower()
    if display == 'yes' or display == 'y':
        print(filtered_city_data.iloc[row:row+5])
        row += 5
        return display_data(filtered_city_data, row)
    if display == 'no' or display == 'n':
        return
    else:
        print('That is not a valid answer. Please try again.')
        return display_data(filtered_city_data, row)
#https://stackoverflow.com/questions/43772362/how-to-print-a-specific-row-of-a-pandas-dataframe
#https://pandas.pydata.org/pandas-docs/stable/indexing.html

# %%
def main():
    """
    Loads analysis and data for the specified city and filters.
    """
    # 1) pick a city   
    city = get_city()
    print('Great! We\'ll use %s.' % city)
    
    # 2) load data
    raw_city_data = get_raw_city_data(city)
    
    #3) clean data
    clean_data(raw_city_data)
 
    #4) parse data
    parse_data(raw_city_data)
    
    #5) filter data
    filtered_city_data = filter_data(raw_city_data)
    
    #6) display statistics
    display_statistics(filtered_city_data)
    
    #7) display statistics on most popular month and day overall
    display_month_day_hour_statistics(filtered_city_data)
    
    #8) see data details
    see_data = display_data(filtered_city_data, row=76)

    #9) restart if you wish
    restart = input('\nWould you like to restart? Enter yes or no.\n')
    if restart.lower() == 'yes' or restart.lower() == 'y':
        main()
    elif restart.lower() == 'no' or restart.lower() == 'n':
        return
    else:
        print("\nThat is not a valid answer. Please try again.")
        return restart()

# %%
if __name__ == "__main__":
	main()
# Out:
# Hello! Let's explore some US bikeshare data!
# Would you like to see data for Chicago, New York, or Washington?
# chicago
# Great! We'll use chicago.
# Would you like to filter the data by month, day, or not at all? Type "none" for no time filter.
# month
# Great! Time period selected: month
# Select a month, January - June
# may
# Great! We'll use may.
#
#
# -------------------------------------
#
# Station Info:
# Popular Start Station:  Streeter Dr & Grand Ave
# Popular End Station:  Streeter Dr & Grand Ave
# Popular Journey:  Lake Shore Dr & Monroe St to Streeter Dr & Gra...
#
# Other Ridership Data:
# Total Time Travel: 65175363
# Mean Time Travel: 976.3367987416673
#
# User Info:
# Subscriber    51020
# Customer      15735
# Name: user_type, dtype: int64
#
#
# Male      38284
# Female    12750
# Name: gender, dtype: int64
# The oldest birth year in the dataset is listed as 1899.
# The most recent birth year in the dataset is 2016.
# The most common birth year in the dataset is 1989.
#
#
#
#
# -------------------------------------
#
# Trip Info:
# 5 is the month with the highest ridership
# Monday is the day of the week with the highest ridership
# 17 is the most common trip start hour
#
# Would you like to view individual trip data? Type 'yes' or 'no'.
# no
#
# Would you like to restart? Enter yes or no.
# no
